# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamHooda01/Data-Science-Projects/blob/main/New_York_shelter_demand_using_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import itertools
from prophet import Prophet

# %% [markdown]
# # Get The Data

# %%
data = pd.read_csv('/content/DHS_Daily_Report_2020.csv')

# %%
data.head()
# Out:
#        Date  Total Adults in Shelter  Total Children in Shelter  \
# 0  1/1/2014                    28770                      21919
# 1  1/2/2014                    28843                      21954
# 2  1/3/2014                    28947                      22007
# 3  1/4/2014                    28954                      22003
# 4  1/5/2014                    28991                      21966
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         50689                         7269
# 1                         50797                         7289
# 2                         50954                         7323
# 3                         50957                         7320
# 4                         50957                         7386
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           2650                            9919
# 1                           2661                            9950
# 2                           2678                           10001
# 3                           2684                           10004
# 4                           2692                           10078
#
#    Families with Children in Shelter  \
# 0                              10469
# 1                              10484
# 2                              10521
# 3                              10520
# 4                              10502
#
#    Adults in Families with Children in Shelter  \
# 0                                        14897
# 1                                        14930
# 2                                        14978
# 3                                        14971
# 4                                        14941
#
#    Children in Families with Children in Shelter  \
# 0                                          21919
# 1                                          21954
# 2                                          22007
# 3                                          22003
# 4                                          21966
#
#    Total Individuals in Families with Children in Shelter   \
# 0                                               1866
# 1                                               1871
# 2                                               1872
# 3                                               1877
# 4                                               1874
#
#    Adult Families in Shelter  Easter  Thanksgiving  Christmas
# 0                       3954       0             0          0
# 1                       3963       0             0          0
# 2                       3968       0             0          0
# 3                       3979       0             0          0
# 4                       3972       0             0          0

# %% [markdown]
# # Data Preparation

# %%
data.Date = pd.to_datetime(data.Date,
                           format = '%m/%d/%Y')
data.Date
# Out:
# 0      2014-01-01
# 1      2014-01-02
# 2      2014-01-03
# 3      2014-01-04
# 4      2014-01-05
#           ...
# 2552   2020-12-27
# 2553   2020-12-28
# 2554   2020-12-29
# 2555   2020-12-30
# 2556   2020-12-31
# Name: Date, Length: 2557, dtype: datetime64[ns]

# %%
df = data.loc[data.Date < '2020-12-01',
              ['Date', 'Total Individuals in Shelter', 'Easter', 'Christmas', 'Thanksgiving']]

# %%
df.head()
# Out:
#         Date  Total Individuals in Shelter  Easter  Christmas  Thanksgiving
# 0 2014-01-01                         50689       0          0             0
# 1 2014-01-02                         50797       0          0             0
# 2 2014-01-03                         50954       0          0             0
# 3 2014-01-04                         50957       0          0             0
# 4 2014-01-05                         50957       0          0             0

# %%
df = df.rename(columns = {'Total Individuals in Shelter':'y', 'Date':'ds'})
df.head(1)
# Out:
#           ds      y  Easter  Christmas  Thanksgiving
# 0 2014-01-01  50689       0          0             0

# %% [markdown]
# # Holidays

# %%
# Easter holiday
easter_dates = df[df.Easter == 1].ds
easter = pd.DataFrame({'holiday':'easter',
                       'ds': pd.to_datetime(easter_dates),
                         'lower_window': -5,
                         'upper_window': 2})
easter.head()
# Out:
#      holiday         ds  lower_window  upper_window
# 109   easter 2014-04-20            -5             2
# 459   easter 2015-04-05            -5             2
# 816   easter 2016-03-27            -5             2
# 1201  easter 2017-04-16            -5             2
# 1551  easter 2018-04-01            -5             2

# %%
# Thanksgiving holiday
thanksgiving_dates = df[df.Thanksgiving == 1].ds
thanksgiving = pd.DataFrame({'holiday':'thanksgiving',
                       'ds': pd.to_datetime(thanksgiving_dates),
                         'lower_window': -5,
                          'upper_window': 2})
thanksgiving.head()
# Out:
#            holiday         ds  lower_window  upper_window
# 330   thanksgiving 2014-11-27            -5             2
# 694   thanksgiving 2015-11-26            -5             2
# 1058  thanksgiving 2016-11-24            -5             2
# 1422  thanksgiving 2017-11-23            -5             2
# 1786  thanksgiving 2018-11-22            -5             2

# %%
holidays = pd.concat([easter, thanksgiving])
holidays.sample(5)
# Out:
#            holiday         ds  lower_window  upper_window
# 1201        easter 2017-04-16            -5             2
# 1936        easter 2019-04-21            -5             2
# 2157  thanksgiving 2019-11-28            -5             2
# 694   thanksgiving 2015-11-26            -5             2
# 1422  thanksgiving 2017-11-23            -5             2

# %% [markdown]
# # Model

# %%
#prophet model
model = Prophet(growth = 'linear',
                holidays = holidays,
                seasonality_mode= 'multiplicative',
                seasonality_prior_scale= 10,
                holidays_prior_scale= 10,
                changepoint_prior_scale= .05,)
model.add_regressor('Christmas')
model.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ngp6qfq4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/6hut1r3w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51369', 'data', 'file=/tmp/tmpoe6fl4f4/ngp6qfq4.json', 'init=/tmp/tmpoe6fl4f4/6hut1r3w.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model8dq8aa4c/prophet_model-20240114160535.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:05:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Cross Validation

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, horizon = '31',
                         initial = '2400 days',
                         parallel= 'processes')
# Out:
# INFO:prophet:Making 125 forecasts with cutoffs between 2020-07-28 23:59:59.999999969 and 2020-11-29 23:59:59.999999969
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x79e316c06d40>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/zw8xcjx4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ijvp_gky.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/j9omc0er.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86748', 'data', 'file=/tmp/tmpoe6fl4f4/zw8xcjx4.json', 'init=/tmp/tmpoe6fl4f4/j9omc0er.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelrye2azph/prophet_model-20240114160539.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/rvbdmt9c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42943', 'data', 'file=/tmp/tmpoe6fl4f4/ijvp_gky.json', 'init=/tmp/tmpoe6fl4f4/rvbdmt9c.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelkmlueqqg/prophet_model-20240114160539.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:05:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/wul_pwhe.json
# 16:05:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/zj3poes5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42550', 'data', 'file=/tmp/tmpoe6fl4f4/wul_pwhe.json', 'init=/tmp/tmpoe6fl4f4/zj3poes5.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelqvgncua5/prophet_model-20240114160542.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/7k803jwu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/_5q97d5d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17217', 'data', 'file=/tmp/tmpoe6fl4f4/7k803jwu.json', 'init=/tmp/tmpoe6fl4f4/_5q97d5d.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model_6md7nu1/prophet_model-20240114160542.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:05:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/n1ua6edn.json
# 16:05:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/nsm5c1ag.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72726', 'data', 'file=/tmp/tmpoe6fl4f4/n1ua6edn.json', 'init=/tmp/tmpoe6fl4f4/nsm5c1ag.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelqerd1akc/prophet_model-20240114160546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:46 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/txgp30xx.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/_yn37_qb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56091', 'data', 'file=/tmp/tmpoe6fl4f4/txgp30xx.json', 'init=/tmp/tmpoe6fl4f4/_yn37_qb.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modeljyhy21as/prophet_model-20240114160546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:05:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:05:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96521', 'data', 'file=/tmp/tmpoe6fl4f4/_7zswacd.json', 'init=/tmp/tmpoe6fl4f4/_mgct1dl.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model96azoflo/prophet_model-20240114160932.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/sqofis5x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/h4cksq4p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58874', 'data', 'file=/tmp/tmpoe6fl4f4/sqofis5x.json', 'init=/tmp/tmpoe6fl4f4/h4cksq4p.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model7v72lyzb/prophet_model-20240114160935.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ezfy54ic.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/4lr_8dz1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67592', 'data', 'file=/tmp/tmpoe6fl4f4/ezfy54ic.json', 'init=/tmp/tmpoe6fl4f4/4lr_8dz1.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelcu6yaxgs/prophet_model-20240114160936.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/4t96lsxi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/cv97k1he.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24286', 'data', 'file=/tmp/tmpoe6fl4f4/4t96lsxi.json', 'init=/tmp/tmpoe6fl4f4/cv97k1he.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model9lki2ym_/prophet_model-20240114160938.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/xdh6k2wq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/zhkwfrwi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10662', 'data', 'file=/tmp/tmpoe6fl4f4/xdh6k2wq.json', 'init=/tmp/tmpoe6fl4f4/zhkwfrwi.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelxz2tip99/prophet_model-20240114160939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 16:09:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/2zc1ad_2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/jwpzm8fn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/kbpzfk9_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32940', 'data', 'file=/tmp/tmpoe6fl4f4/2zc1ad_2.json', 'init=/tmp/tmpoe6fl4f4/kbpzfk9_.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modely6djedql/prophet_model-20240114160944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/0071s0nl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30897', 'data', 'file=/tmp/tmpoe6fl4f4/jwpzm8fn.json', 'init=/tmp/tmpoe6fl4f4/0071s0nl.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelegme_ubv/prophet_model-20240114160944.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:09:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:09:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 16:09:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Model Assessment

# %%
from sklearn.metrics import mean_absolute_error
print(f'Mean Absolute Error: {round(mean_absolute_error(df_cv.y, df_cv.yhat),2)}')
# Out:
# Mean Absolute Error: 1507.95

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#parameter grid
from sklearn.model_selection import  ParameterGrid

# %%
param_grid = {'seasonality_prior_scale': [10,20],
              'changepoint_prior_scale': [.01,.1],
              'holidays_prior_scale': [5,20],}
param_grid
# Out:
# {'seasonality_prior_scale': [10, 20],
#  'changepoint_prior_scale': [0.01, 0.1],
#  'holidays_prior_scale': [5, 20]}

# %%
grid = ParameterGrid(param_grid)
len(list(grid))
# Out:
# 8

# %%
#Tuning
mae = []
for param in grid:
  #Build the model
  model = Prophet(growth = 'linear',
                holidays = holidays,
                seasonality_mode= 'multiplicative',
                seasonality_prior_scale= param['seasonality_prior_scale'],
                holidays_prior_scale= param['holidays_prior_scale'],
                changepoint_prior_scale=param['changepoint_prior_scale'])
  model.add_regressor('Christmas')
  model.fit(df)

  #crossvalidation
  df_cv = cross_validation(model, horizon = '31',
                         initial = '2400 days',
                         parallel= 'processes')

  # Get the results
  error = round(mean_absolute_error(df_cv.y, df_cv.yhat),2)
  mae.append(error)
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/6lcpc19k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/h1b_it_k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88306', 'data', 'file=/tmp/tmpoe6fl4f4/6lcpc19k.json', 'init=/tmp/tmpoe6fl4f4/h1b_it_k.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model3r3l_0xs/prophet_model-20240114162550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:25:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:25:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/qjou0ajp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/9q78l0d4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18913', 'data', 'file=/tmp/tmpoe6fl4f4/qjou0ajp.json', 'init=/tmp/tmpoe6fl4f4/9q78l0d4.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46044', 'data', 'file=/tmp/tmpoe6fl4f4/xh9mpo9p.json', 'init=/tmp/tmpoe6fl4f4/svl85fc5.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelw8ncayh1/prophet_model-20240114164344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/rn_t67z6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/maff_uzn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15401', 'data', 'file=/tmp/tmpoe6fl4f4/rn_t67z6.json', 'init=/tmp/tmpoe6fl4f4/maff_uzn.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modeljmna0jfu/prophet_model-20240114164346.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/p0_9soav.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/accimpz7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 16:43:48 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87551', 'data', 'file=/tmp/tmpoe6fl4f4/p0_9soav.json', 'init=/tmp/tmpoe6fl4f4/accimpz7.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modell3sk2rxw/prophet_model-20240114164348.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/d6l0xs0y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ytf5vah8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92636', 'data', 'file=/tmp/tmpoe6fl4f4/d6l0xs0y.json', 'init=/tmp/tmpoe6fl4f4/ytf5vah8.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelnpi5nzrj/prophet_model-20240114164349.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/dhv98r0r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/u_fzlhay.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73199', 'data', 'file=/tmp/tmpoe6fl4f4/dhv98r0r.json', 'init=/tmp/tmpoe6fl4f4/u_fzlhay.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelnudxrg98/prophet_model-20240114164352.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/05o_u09h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/3wfdzom6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75001', 'data', 'file=/tmp/tmpoe6fl4f4/05o_u09h.json', 'init=/tmp/tmpoe6fl4f4/3wfdzom6.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelw8fp2y3r/prophet_model-20240114164354.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/e9zdyfy5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/y23r5zar.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15615', 'data', 'file=/tmp/tmpoe6fl4f4/e9zdyfy5.json', 'init=/tmp/tmpoe6fl4f4/y23r5zar.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model_o39946t/prophet_model-20240114164356.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ads2aa0c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/j16cmjop.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61617', 'data', 'file=/tmp/tmpoe6fl4f4/ads2aa0c.json', 'init=/tmp/tmpoe6fl4f4/j16cmjop.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model0otyc87c/prophet_model-20240114164358.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:43:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:43:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/ypmcsb6r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/lqb1ofc1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51777', 'data', 'file=/tmp/tmpoe6fl4f4/ypmcsb6r.json', 'init=/tmp/tmpoe6fl4f4/lqb1ofc1.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelov9hj4u2/prophet_model-20240114164400.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:44:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:44:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/avu81zgy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/djtarnut.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78896', 'data', 'file=/tmp/tmpoe6fl4f4/avu81zgy.json', 'init=/tmp/tmpoe6fl4f4/djtarnut.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelhsabgs9y/prophet_model-20240114164402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:44:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:44:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/2b72rqvt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/rsouwvrt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4321', 'data', 'file=/tmp/tmpoe6fl4f4/2b72rqvt.json', 'init=/tmp/tmpoe6fl4f4/rsouwvrt.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelutdw0fls/prophet_model-20240114164404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:44:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:44:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/d1gy6i3k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/2jwxd4v8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50635', 'data', 'file=/tmp/tmpoe6fl4f4/d1gy6i3k.json', 'init=/tmp/tmpoe6fl4f4/2jwxd4v8.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_modelamk9uyx1/prophet_model-20240114164406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:44:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:44:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/vzcopact.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpoe6fl4f4/j7yic2z4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26294', 'data', 'file=/tmp/tmpoe6fl4f4/vzcopact.json', 'init=/tmp/tmpoe6fl4f4/j7yic2z4.json', 'output', 'file=/tmp/tmpoe6fl4f4/prophet_model6dtqw7jh/prophet_model-20240114164409.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:44:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:44:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 16:44:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Best Parameters

# %%
best_params = grid[np.argmin(mae)]
print(f'Best params: {best_params}')
# Out:
# Best params: {'seasonality_prior_scale': 10, 'holidays_prior_scale': 5, 'changepoint_prior_scale': 0.1}
